# %% [markdown]
# # VulRAG CPG Extraction - Complete Pipeline
# ## Optimized Version with Parallelization
#
# This notebook:
# 1. Extracts all uniques instances from the VulRAG KB dataset
# 2. Generates .c files in an organized structure
# 3. Launches parallel CPG extraction using Joern
# 4. Produces the KB2 dataset with CPGs in JSON format

# %% [markdown]
# # Cell 1: Imports and Configuration

# %%
import json
import os
import sys
import subprocess
import shutil
import time
from pathlib import Path
from collections import defaultdict, Counter
from datetime import datetime
import pandas as pd
from IPython.display import display, HTML, clear_output
import warnings
import hashlib
warnings.filterwarnings('ignore')

# Path configuration
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
VULRAG_KB_DIR = PROJECT_ROOT / 'data' / 'raw' / 'vulrag_kb'
DATA_TMP = PROJECT_ROOT / 'data' / 'tmp'
CPG_JSON_DIR = DATA_TMP / 'cpg_json'
KB2_OUTPUT = PROJECT_ROOT / 'data' / 'processed' 
SCRIPTS_DIR = PROJECT_ROOT / 'scripts'
RESULTS_DIR = PROJECT_ROOT / 'results' / 'cpg_extraction'


# Create necessary directories
for dir_path in [DATA_TMP, CPG_JSON_DIR, KB2_OUTPUT, SCRIPTS_DIR, RESULTS_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

print("VulRAG CPG Extraction Pipeline")
print("=" * 50)
print(f"Project root: {PROJECT_ROOT}")
print(f"VulRAG KB: {VULRAG_KB_DIR}")
print(f"CPG output: {CPG_JSON_DIR}")
print(f"KB2 final: {KB2_OUTPUT}")
print(f"Results: {RESULTS_DIR}")
# Out:
# VulRAG CPG Extraction Pipeline
# ==================================================
# Project root: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System
# VulRAG KB: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/raw/vulrag_kb
# CPG output: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/cpg_json
# KB2 final: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/processed
# Results: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/results/cpg_extraction

# %% [markdown]
# #  KB1 Dataset Validation

# %%
print("\nSTEP 1: VALIDATE KB1 DATASET")
print("=" * 50)

if not VULRAG_KB_DIR.exists():
    print("ERROR: VulRAG KB directory not found!")
    print(f"Expected at: {VULRAG_KB_DIR}")
    raise FileNotFoundError("Please run download_data.sh first")

kb_files = list(VULRAG_KB_DIR.glob("*.json"))
print(f"Found {len(kb_files)} JSON files:")

total_size_mb = 0
for file in sorted(kb_files):
    file_size_mb = file.stat().st_size / (1024 * 1024)
    total_size_mb += file_size_mb
    print(f"   {file.name} ({file_size_mb:.1f} MB)")

print(f"\nTotal dataset size: {total_size_mb:.1f} MB")
# Out:
# STEP 1: VALIDATE KB1 DATASET
# ==================================================
# Found 10 JSON files:
#    gpt-4o-mini_CWE-119_316.json (1.7 MB)
#    gpt-4o-mini_CWE-125_316.json (1.5 MB)
#    gpt-4o-mini_CWE-200_316.json (1.3 MB)
#    gpt-4o-mini_CWE-20_316.json (1.7 MB)
#    gpt-4o-mini_CWE-264_316.json (1.1 MB)
#    gpt-4o-mini_CWE-362_316.json (2.9 MB)
#    gpt-4o-mini_CWE-401_316.json (0.8 MB)
#    gpt-4o-mini_CWE-416_316.json (5.7 MB)
#    gpt-4o-mini_CWE-476_316.json (2.6 MB)
#    gpt-4o-mini_CWE-787_316.json (2.0 MB)
#
# Total dataset size: 21.2 MB

# %%
def extract_code_to_files(vulrag_kb_dir, output_dir=DATA_TMP / "temp_code_files"):
    """
    Extract code instances from VulRAG KB to separate files
    Uses unique keys to prevent metadata overwrites
    """
    
    print("Extracting code files from VulRAG KB...")
    print("=" * 50)
    
    # Create output structure
    output_path = Path(output_dir)
    output_path.mkdir(exist_ok=True, parents=True)
    
    # Global metadata
    metadata = {
        'extraction_info': {
            'timestamp': str(pd.Timestamp.now()),
            'source_directory': str(vulrag_kb_dir),
            'output_directory': str(output_path)
        },
        'statistics': {
            'total_files_processed': 0,
            'total_instances': 0,
            'total_code_files_created': 0,
            'empty_code_instances': 0,
            'by_cwe': {}
        },
        'file_mappings': {},
        'instance_mappings': {}
    }
    
    global_instance_counter = 0
    
    # Process each CWE file
    for kb_file in sorted(vulrag_kb_dir.glob("*.json")):
        cwe = kb_file.stem.split('_')[1]  # Extract CWE-XXX
        
        print(f"Processing {kb_file.name}...")
        
        # Create CWE directory
        cwe_dir = output_path / cwe
        cwe_dir.mkdir(exist_ok=True)
        
        with open(kb_file, 'r', encoding='utf-8') as f:
            cwe_data = json.load(f)
        
        cwe_stats = {
            'source_file': kb_file.name,
            'cve_count': len(cwe_data.keys()),
            'instance_count': 0,
            'code_files_created': 0,
            'empty_code_instances': 0,
            'instances': {}
        }
        
        # Process each CVE
        for cve_id, instances in cwe_data.items():
            cve_instances = []
            
            for idx, instance in enumerate(instances):
                global_instance_counter += 1
                cwe_stats['instance_count'] += 1
                
                # Extract codes
                vuln_code = instance.get('code_before_change', '').strip()
                patch_code = instance.get('code_after_change', '').strip()
                
                # Handle empty code instances
                is_empty = not vuln_code or not patch_code
                if is_empty:
                    cwe_stats['empty_code_instances'] += 1
                    metadata['statistics']['empty_code_instances'] += 1
                    if not vuln_code:
                        vuln_code = "// Empty vulnerable code"
                    if not patch_code:
                        patch_code = "// Empty patched code"
                
                # Create filenames
                base_name = f"{cve_id}_{idx}"
                vuln_filename = f"{base_name}_vuln.c"
                patch_filename = f"{base_name}_patch.c"
                
                vuln_filepath = cwe_dir / vuln_filename
                patch_filepath = cwe_dir / patch_filename
                
                # Write files
                with open(vuln_filepath, 'w', encoding='utf-8') as f:
                    f.write(vuln_code)
                
                with open(patch_filepath, 'w', encoding='utf-8') as f:
                    f.write(patch_code)
                
                cwe_stats['code_files_created'] += 2
                
                # Instance metadata
                instance_id = f"{cve_id}_{idx}"
                instance_metadata = {
                    'instance_id': instance_id,
                    'cve_id': cve_id,
                    'cwe': cwe,
                    'instance_index': idx,
                    'global_counter': global_instance_counter,
                    'source_file': kb_file.name,
                    'has_empty_code': is_empty,
                    'files': {
                        'vulnerable_code': {
                            'filename': vuln_filename,
                            'full_path': str(vuln_filepath),
                            'relative_path': f"{cwe}/{vuln_filename}",
                            'size_bytes': len(vuln_code.encode('utf-8')),
                            'line_count': len(vuln_code.split('\n'))
                        },
                        'patched_code': {
                            'filename': patch_filename,
                            'full_path': str(patch_filepath),
                            'relative_path': f"{cwe}/{patch_filename}",
                            'size_bytes': len(patch_code.encode('utf-8')),
                            'line_count': len(patch_code.split('\n'))
                        }
                    },
                    'additional_info': {
                        'vulnerability_type': instance.get('preconditions_for_vulnerability', ''),
                        'trigger_condition': instance.get('trigger_condition', ''),
                        'solution': instance.get('solution', ''),
                        'gpt_purpose': instance.get('GPT_purpose', ''),
                        'modified_lines': instance.get('modified_lines', {})
                    }
                }
                
                cve_instances.append(instance_metadata)
                
                # Use unique keys for file mappings
                unique_vuln_key = f"{cwe}_{vuln_filename}"
                unique_patch_key = f"{cwe}_{patch_filename}"
                
                metadata['file_mappings'][unique_vuln_key] = instance_metadata
                metadata['file_mappings'][unique_patch_key] = instance_metadata
                metadata['instance_mappings'][instance_id] = instance_metadata
            
            if cve_instances:
                cwe_stats['instances'][cve_id] = cve_instances
        
        metadata['statistics']['by_cwe'][cwe] = cwe_stats
        metadata['statistics']['total_files_processed'] += 1
        metadata['statistics']['total_instances'] += cwe_stats['instance_count']
        metadata['statistics']['total_code_files_created'] += cwe_stats['code_files_created']
        
        print(f"   Created {cwe_stats['code_files_created']} files from {cwe_stats['instance_count']} instances")
    
    # Save metadata
    metadata_file = output_path / "metadata.json"
    with open(metadata_file, 'w', encoding='utf-8') as f:
        json.dump(metadata, f, indent=2, ensure_ascii=False)
    
   
    
    # Summary
    print(f"\nExtraction completed")
    print(f"Output directory: {output_path}")
    print(f"Files processed: {metadata['statistics']['total_files_processed']}")
    print(f"Total instances: {metadata['statistics']['total_instances']}")
    print(f"Code files created: {metadata['statistics']['total_code_files_created']}")
    print(f"Empty code instances: {metadata['statistics']['empty_code_instances']}")
    
    return metadata

# Run extraction using existing path variables
metadata = extract_code_to_files(VULRAG_KB_DIR)
# Out:
# Extracting code files from VulRAG KB...
# ==================================================
# Processing gpt-4o-mini_CWE-119_316.json...
#    Created 346 files from 173 instances
# Processing gpt-4o-mini_CWE-125_316.json...
#    Created 280 files from 140 instances
# Processing gpt-4o-mini_CWE-200_316.json...
#    Created 306 files from 153 instances
# Processing gpt-4o-mini_CWE-20_316.json...
#    Created 364 files from 182 instances
# Processing gpt-4o-mini_CWE-264_316.json...
#    Created 240 files from 120 instances
# Processing gpt-4o-mini_CWE-362_316.json...
#    Created 640 files from 320 instances
# Processing gpt-4o-mini_CWE-401_316.json...
#    Created 202 files from 101 instances
# Processing gpt-4o-mini_CWE-416_316.json...
#    Created 1320 files from 660 instances
# Processing gpt-4o-mini_CWE-476_316.json...
#    Created 562 files from 281 instances
# Processing gpt-4o-mini_CWE-787_316.json...
#    Created 374 files from 187 instances
#
# Extraction completed
# Output directory: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files
# Files processed: 10
# Total instances: 2317
# Code files created: 4634
# Empty code instances: 0

# %%
def run_cpg_extraction():
    """Lancer l'extraction CPG avec suivi en temps réel"""

    code_files_dir = DATA_TMP / 'temp_code_files'
    cpg_output_dir = CPG_JSON_DIR
    extract_script = SCRIPTS_DIR / 'extract_cpg.sh' 

    if not extract_script.exists():
        print(f"❌ Script not found: {extract_script}")
        return False

    if not os.access(extract_script, os.X_OK):
        print(f"❌ Script not executable: {extract_script}")
        print(f"Run: chmod +x {extract_script}")
        return False

    print(f"🚀 Launching CPG extraction...")
    print(f"Script: {extract_script}")
    print("=" * 50)
    print(f"TEMP_CODE_FILES: {code_files_dir}")

    try:
        result = subprocess.run(
            [str(extract_script), str(code_files_dir), str(cpg_output_dir)],
            cwd=extract_script.parent,
            text=True,
        )

        print("=" * 50)
        if result.returncode == 0:
            print("✅ CPG extraction completed successfully!")
        else:
            print(f"❌ CPG extraction failed with code {result.returncode}")

        return result.returncode == 0

    except KeyboardInterrupt:
        print("\n⏹️ Extraction interrupted by user")
        return False
    except Exception as e:
        print(f"❌ Error running extraction: {e}")
        return False

# Usage
success = run_cpg_extraction()
# Out:
# 🚀 Launching CPG extraction...
# Script: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/scripts/extract_cpg.sh
# ==================================================
# TEMP_CODE_FILES: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files
# === FULL CPG EXTRACTION ===
# Input: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files
# Output: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/cpg_json
# Started: Tue Aug  5 08:18:05 EDT 2025
# Found 2317 pairs to process
#
# Processing CWE-119...
#   [50/2317] Progress: N/A pairs/min
#   [100/2317] Progress: N/A pairs/min
#   [150/2317] Progress: N/A pairs/min
# Processing CWE-125...
#   [200/2317] Progress: N/A pairs/min
#   [250/2317] Progress: N/A pairs/min
#   [300/2317] Progress: 30000.00 pairs/min
# Processing CWE-20...
#   [350/2317] Progress: 35000.00 pairs/min
#   [400/2317] Progress: 40000.00 pairs/min
#   [450/2317] Progress: 45000.00 pairs/min
# Processing CWE-200...
#   [500/2317] Progress: 50000.00 pairs/min
#   [550/2317] Progress: 55000.00 pairs/min
#   [600/2317] Progress: 60000.00 pairs/min
# Processing CWE-264...
#   [650/2317] Progress: 65000.00 pairs/min
#   [700/2317] Progress: 23333.33 pairs/min
#   [750/2317] Progress: 25000.00 pairs/min
# Processing CWE-362...
#   [800/2317] Progress: 26666.66 pairs/min
#   [850/2317] Progress: 28333.33 pairs/min
#   [900/2317] Progress: 30000.00 pairs/min
#   [950/2317] Progress: 31666.66 pairs/min
#   [1000/2317] Progress: 33333.33 pairs/min
#   [1050/2317] Progress: 21000.00 pairs/min
# Processing CWE-401...
#   [1100/2317] Progress: 22000.00 pairs/min
#   [1150/2317] Progress: 23000.00 pairs/min
# Processing CWE-416...
#   [1200/2317] Progress: 24000.00 pairs/min
#   [1250/2317] Progress: 25000.00 pairs/min
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.OqsSMghfc6/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.OqsSMghfc6/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.OqsSMghfc6/code.cpg.bin`
# exported 2146 nodes, 15871 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.OqsSMghfc6/export
# CVE-2018-10876_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XBOFUD4rvp/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XBOFUD4rvp/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XBOFUD4rvp/code.cpg.bin`
# exported 2149 nodes, 15910 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XBOFUD4rvp/export
# CVE-2018-10876_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_2_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_2_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3CFnHMRLzN/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3CFnHMRLzN/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3CFnHMRLzN/code.cpg.bin`
# exported 475 nodes, 2775 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3CFnHMRLzN/export
# CVE-2018-10876_2/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_2_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_2_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.EC4NnJm7ZH/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.EC4NnJm7ZH/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.EC4NnJm7ZH/code.cpg.bin`
# exported 515 nodes, 3054 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.EC4NnJm7ZH/export
# CVE-2018-10876_2/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_3_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_3_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.VWdq8qqg1e/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.VWdq8qqg1e/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.VWdq8qqg1e/code.cpg.bin`
# exported 18 nodes, 42 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.VWdq8qqg1e/export
# CVE-2018-10876_3/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_3_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_3_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gqUq7NvRWy/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gqUq7NvRWy/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gqUq7NvRWy/code.cpg.bin`
# exported 18 nodes, 42 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gqUq7NvRWy/export
# CVE-2018-10876_3/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_4_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_4_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.kAdHxfHZDh/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.kAdHxfHZDh/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.kAdHxfHZDh/code.cpg.bin`
# exported 538 nodes, 3184 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.kAdHxfHZDh/export
# CVE-2018-10876_4/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_4_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10876_4_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.aibn3e6fk2/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.aibn3e6fk2/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.aibn3e6fk2/code.cpg.bin`
# exported 578 nodes, 3463 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.aibn3e6fk2/export
# CVE-2018-10876_4/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10879_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10879_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.zW4CwFheJy/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.zW4CwFheJy/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.zW4CwFheJy/code.cpg.bin`
# exported 560 nodes, 3873 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.zW4CwFheJy/export
# CVE-2018-10879_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10879_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10879_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.M9YkpzrJoq/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.M9YkpzrJoq/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.M9YkpzrJoq/code.cpg.bin`
# exported 660 nodes, 4836 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.M9YkpzrJoq/export
# CVE-2018-10879_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.cneSPxz80F/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.cneSPxz80F/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.cneSPxz80F/code.cpg.bin`
# exported 249 nodes, 1589 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.cneSPxz80F/export
# CVE-2018-10902_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vuoIxCz32f/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vuoIxCz32f/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vuoIxCz32f/code.cpg.bin`
# exported 291 nodes, 1896 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vuoIxCz32f/export
# CVE-2018-10902_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.yOXCxclGB1/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.yOXCxclGB1/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.yOXCxclGB1/code.cpg.bin`
# exported 212 nodes, 1270 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.yOXCxclGB1/export
# CVE-2018-10902_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-10902_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.l3QYZjicy8/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.l3QYZjicy8/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.l3QYZjicy8/code.cpg.bin`
# exported 254 nodes, 1572 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.l3QYZjicy8/export
# CVE-2018-10902_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-11412_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-11412_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.MKnkoKWwID/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.MKnkoKWwID/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.MKnkoKWwID/code.cpg.bin`
# exported 283 nodes, 1638 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.MKnkoKWwID/export
# CVE-2018-11412_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-11412_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-11412_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3Kn01ioZGv/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3Kn01ioZGv/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3Kn01ioZGv/code.cpg.bin`
# exported 310 nodes, 1818 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3Kn01ioZGv/export
# CVE-2018-11412_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14611_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14611_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Q6RT4HUn5m/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Q6RT4HUn5m/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Q6RT4HUn5m/code.cpg.bin`
# exported 404 nodes, 2734 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Q6RT4HUn5m/export
# CVE-2018-14611_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14611_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14611_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.W9gkFgj9LZ/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.W9gkFgj9LZ/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.W9gkFgj9LZ/code.cpg.bin`
# exported 488 nodes, 3467 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.W9gkFgj9LZ/export
# CVE-2018-14611_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.R4gTJDkM60/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.R4gTJDkM60/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.R4gTJDkM60/code.cpg.bin`
# exported 310 nodes, 1756 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.R4gTJDkM60/export
# CVE-2018-14625_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.V6OU3Zidxe/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.V6OU3Zidxe/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.V6OU3Zidxe/code.cpg.bin`
# exported 329 nodes, 1909 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.V6OU3Zidxe/export
# CVE-2018-14625_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.UxFRpjO5Zn/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.UxFRpjO5Zn/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.UxFRpjO5Zn/code.cpg.bin`
# exported 76 nodes, 301 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.UxFRpjO5Zn/export
# CVE-2018-14625_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.14JKtdySvo/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.14JKtdySvo/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.14JKtdySvo/code.cpg.bin`
# exported 100 nodes, 454 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.14JKtdySvo/export
# CVE-2018-14625_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_2_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_2_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gXtdYLdmjS/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gXtdYLdmjS/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gXtdYLdmjS/code.cpg.bin`
# exported 210 nodes, 1107 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gXtdYLdmjS/export
# CVE-2018-14625_2/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_2_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_2_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.eAMfxH1U8r/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.eAMfxH1U8r/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.eAMfxH1U8r/code.cpg.bin`
# exported 221 nodes, 1168 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.eAMfxH1U8r/export
# CVE-2018-14625_2/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_3_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_3_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gNf3s22Dvj/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gNf3s22Dvj/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gNf3s22Dvj/code.cpg.bin`
# exported 181 nodes, 974 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.gNf3s22Dvj/export
# CVE-2018-14625_3/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_3_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_3_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CNRbjpCZar/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CNRbjpCZar/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CNRbjpCZar/code.cpg.bin`
# exported 194 nodes, 1036 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CNRbjpCZar/export
# CVE-2018-14625_3/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_4_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_4_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.NOfHbjdFCP/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.NOfHbjdFCP/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.NOfHbjdFCP/code.cpg.bin`
# exported 174 nodes, 880 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.NOfHbjdFCP/export
# CVE-2018-14625_4/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_4_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14625_4_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Y28InbpUD2/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Y28InbpUD2/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Y28InbpUD2/code.cpg.bin`
# exported 206 nodes, 1102 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.Y28InbpUD2/export
# CVE-2018-14625_4/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.ekqe9gKAzb/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.ekqe9gKAzb/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.ekqe9gKAzb/code.cpg.bin`
# exported 451 nodes, 2817 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.ekqe9gKAzb/export
# CVE-2018-14734_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.LihgxAd8IH/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.LihgxAd8IH/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.LihgxAd8IH/code.cpg.bin`
# exported 473 nodes, 2997 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.LihgxAd8IH/export
# CVE-2018-14734_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.PLogsAvqNf/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.PLogsAvqNf/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.PLogsAvqNf/code.cpg.bin`
# exported 184 nodes, 972 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.PLogsAvqNf/export
# CVE-2018-14734_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-14734_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.GVksjMSIyl/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.GVksjMSIyl/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.GVksjMSIyl/code.cpg.bin`
# exported 184 nodes, 970 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.GVksjMSIyl/export
# CVE-2018-14734_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-16882_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-16882_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.7dVT0tUt1f/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.7dVT0tUt1f/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.7dVT0tUt1f/code.cpg.bin`
# exported 446 nodes, 2949 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.7dVT0tUt1f/export
# CVE-2018-16882_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-16882_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-416/CVE-2018-16882_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.kPq18AoSXA/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# ...
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.bednEThYuT/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.bednEThYuT/code.cpg.bin`
# exported 158 nodes, 833 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.bednEThYuT/export
# CVE-2023-45863_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.hDQX5A292J/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.hDQX5A292J/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.hDQX5A292J/code.cpg.bin`
# exported 181 nodes, 967 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.hDQX5A292J/export
# CVE-2023-45863_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CHCVLAtpQJ/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CHCVLAtpQJ/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CHCVLAtpQJ/code.cpg.bin`
# exported 109 nodes, 513 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.CHCVLAtpQJ/export
# CVE-2023-45863_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-45863_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.uAKR5KYcCn/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.uAKR5KYcCn/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.uAKR5KYcCn/code.cpg.bin`
# exported 120 nodes, 576 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.uAKR5KYcCn/export
# CVE-2023-45863_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.m2lDZ41IAj/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.m2lDZ41IAj/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.m2lDZ41IAj/code.cpg.bin`
# exported 182 nodes, 1010 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.m2lDZ41IAj/export
# CVE-2023-5717_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3C2fh32rv9/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3C2fh32rv9/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3C2fh32rv9/code.cpg.bin`
# exported 189 nodes, 1077 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.3C2fh32rv9/export
# CVE-2023-5717_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XVMwT3YRtm/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XVMwT3YRtm/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XVMwT3YRtm/code.cpg.bin`
# exported 294 nodes, 1906 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.XVMwT3YRtm/export
# CVE-2023-5717_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-5717_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.qcZ0My0KNv/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.qcZ0My0KNv/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.qcZ0My0KNv/code.cpg.bin`
# exported 352 nodes, 2320 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.qcZ0My0KNv/export
# CVE-2023-5717_1/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_0_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_0_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vwB0u1ehYs/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vwB0u1ehYs/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vwB0u1ehYs/code.cpg.bin`
# exported 157 nodes, 761 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.vwB0u1ehYs/export
# CVE-2023-6931_0/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_0_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_0_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.9OIOIW7Dra/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.9OIOIW7Dra/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.9OIOIW7Dra/code.cpg.bin`
# exported 165 nodes, 921 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.9OIOIW7Dra/export
# CVE-2023-6931_0/patch OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_1_vuln.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_1_vuln.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.emjyxP2jOS/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.emjyxP2jOS/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.emjyxP2jOS/code.cpg.bin`
# exported 73 nodes, 304 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.emjyxP2jOS/export
# CVE-2023-6931_1/vuln OK
# Parsing code at: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_1_patch.c - language: `NEWC`
# [+] Running language frontend
# =======================================================================================================
# Invoking CPG generator in a separate process. Note that the new process will consume additional memory.
# If you are importing a large codebase (and/or running into memory issues), please try the following:
# 1) exit joern
# 2) invoke the frontend: /opt/joern/joern-cli/c2cpg.sh -J-Xmx4096m /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/temp_code_files/CWE-787/CVE-2023-6931_1_patch.c --output /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.FLrBeSaLb0/code.cpg.bin
# 3) start joern, import the cpg: `importCpg("path/to/cpg")`
# =======================================================================================================
#
# [+] Applying default overlays
# Successfully wrote graph to: /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.FLrBeSaLb0/code.cpg.bin
# To load the graph, type `joern /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.FLrBeSaLb0/code.cpg.bin`
# exported 88 nodes, 399 edges into /var/folders/2q/8hm3spnj0xv1qc_zp8111j700000gn/T/tmp.FLrBeSaLb0/export
# CVE-2023-6931_1/patch OK
#
# === FINAL RESULTS ===
# Finished: Tue Aug  5 10:13:36 EDT 2025
# Total time: 6928s (115m)
# Pairs processed: 2317
# CPG files created:     4634
# Expected files: 4634
# Success rate: 100.0%
#
# Output directory: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/cpg_json
# Log file: /Users/vernetemmanueladjobi/Documents/RessourcesStages/Projets/VulRAG-Hybrid-System/data/tmp/cpg_json/extract.log
# ==================================================
# ✅ CPG extraction completed successfully!
